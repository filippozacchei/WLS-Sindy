# %% [markdown]
# # Tutorial 2
#
# This notebook shows how to run multi-fidelity sindy in a simple ODE system with heteroskedastic noise.

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm 

import pysindy as ps
from pysindy.feature_library import WeakPDELibrary
from mfsindy import WeightedWeakPDELibrary  # custom GLS version

# %% [markdown]
# ## 1. Synthetic test problem: scalar linear ODE
#
# Consider
# $$
# \frac{du}{dt} = \lambda u, \qquad \lambda = -0.5.
# $$
#
# The analytic solution with initial condition $u(0) = u_0$ is
# $$
# u(t) = u_0 e^{\lambda t}.
# $$
#
# SINDy is given noisy observations of $u(t)$. The weak library integrates in time and constructs weak derivatives. The goal is to identify the correct equation
# $$
# u_t = \lambda u
# $$
# from the candidate features $[u, u^2]$ in a polynomial library of degree 2.

# %%
# true parameter
lam_true = -0.5

# time grid
T_final = 5.0
Nt = 400
t_eval = np.linspace(0.0, T_final, Nt)

# initial condition and analytic solution
u0 = 1.0
u_clean = u0 * np.exp(lam_true * t_eval)        # shape (Nt,)
u_clean = u_clean[:, None]                      # shape (Nt, 1) for SINDy

# %% [markdown]
# ## 2. Heteroskedastic noise and variance field
#
# Define a time-dependent noise variance
# $$
# \sigma(t)^2 = \sigma_0^2 (1 + \alpha t^2),
# $$
# and generate noisy observations
# $$
# u^{\text{noisy}}(t_i) = u(t_i) + \eta_i, \quad \eta_i \sim \mathcal{N}(0,\sigma(t_i)^2).
# $$
#
# The same variance field $\sigma^2(t)$ is passed to `WeightedWeakPDELibrary` as `spatiotemporal_weights`.

# %%
# %% 2. Define heteroskedastic noise model

sigma0 = 0.02     # base noise std
alpha = 1.5       # heteroskedasticity strength

sigma_t = sigma0 * np.sqrt(1.0 + alpha * t_eval**2)  # std over time, shape (Nt,)
sigma2_t = sigma_t**2                                # variance


def add_noise(u_clean, rng):
    """Add heteroskedastic noise to u_clean(t)."""
    # make sigma_t 2D so it broadcasts with (Nt, 1)
    sigma_2d = sigma_t[:, None]        # shape (Nt, 1)
    noise = rng.normal(loc=0.0, scale=sigma_2d, size=u_clean.shape)
    return u_clean + noise

rng = np.random.default_rng(0)

U_noisy = add_noise(u_clean, rng)  # shape (Nt, 1)
plt.plot(u_clean)
plt.plot(U_noisy)

# %% [markdown]
# ## 3. Weak libraries (unweighted vs weighted)
#
# The spatiotemporal grid is only time here, so
# $$
# X_T = t_{\text{eval}} \in \mathbb{R}^{N_t \times 1}.
# $$
# The variance field is passed with the same shape,
# $$
# \text{spatiotemporal\_weights} \in \mathbb{R}^{N_t \times 1},
# $$
# interpreted as a variance $\sigma^2(t_i)$ at each time point.
#
# Three libraries are constructed:
#
# 1. `weak_lib`: unweighted weak SINDy (no variance information).
# 2. `weighted_weak_lib`: GLS with the true variance $\sigma^2(t)$.
# 3. `weighted_weak_lib2`: GLS with constant weights (control).

# %%
# %% 3. Construct weak libraries and SINDy models

XT = t_eval[:, None]   # shape (Nt, 1)

# base polynomial library Φ(u) = [u, u^2]
base_library = ps.PolynomialLibrary(degree=1, include_bias=False)

# variance field with shape (Nt, 1)
spatiotemporal_weights = sigma2_t[:, None]

# optionally rescale the weights if needed for conditioning
# (for example, divide by mean variance)
spatiotemporal_weights_scaled = spatiotemporal_weights / np.mean(spatiotemporal_weights)

# 3.1 unweighted weak library
weak_lib = WeakPDELibrary(
    function_library=base_library,
    derivative_order=1,
    spatiotemporal_grid=XT,
    is_uniform=True,
    include_bias=False,
)

# 3.2 weighted weak library with variance-based GLS
weighted_weak_lib = WeightedWeakPDELibrary(
    function_library=base_library,
    derivative_order=1,
    spatiotemporal_grid=XT,
    spatiotemporal_weights=spatiotemporal_weights_scaled,
    is_uniform=True,
    include_bias=False,
)

# 3.3 weighted weak library with constant weights (control)
weighted_weak_lib2 = WeightedWeakPDELibrary(
    function_library=base_library,
    derivative_order=1,
    spatiotemporal_grid=XT,
    spatiotemporal_weights=np.ones_like(spatiotemporal_weights_scaled),
    is_uniform=True,
    include_bias=False,
)

# Optimizers: use bagged STLSQ for robustness
opt1 = ps.EnsembleOptimizer(ps.STLSQ(threshold=0.1),
                            bagging=True, n_models=100)
opt2 = ps.EnsembleOptimizer(ps.STLSQ(threshold=0.1),
                            bagging=True, n_models=100)
opt3 = ps.EnsembleOptimizer(ps.STLSQ(threshold=0.1),
                            bagging=True, n_models=100)

# SINDy models corresponding to the three libraries
model_weak      = ps.SINDy(feature_library=weak_lib,          optimizer=opt1)
model_weighted  = ps.SINDy(feature_library=weighted_weak_lib, optimizer=opt2)
model_weighted2 = ps.SINDy(feature_library=weighted_weak_lib2,optimizer=opt3)
# Out:
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/feature_library/weak_pde_library.py:177: UserWarning: is_uniform and periodic have been deprecated.in favor of differetiation_method and diff_kwargs.
#   warnings.warn(

# %% [markdown]
# ## 4. Single realisation: fit and inspect models
#
# Fit all three models on a single noisy trajectory and compare the identified
# coefficients with the true value $\lambda^\star = -0.5$.
#
# The polynomial library with degree 2 and a single state yields features
# $$
# \Phi(u) = [u, u^2],
# $$
# so the true coefficient vector is $[\lambda^\star, 0]$.

# %%
# %% 4. Fit once and inspect coefficients

rng = np.random.default_rng(0)

U_noisy = add_noise(u_clean, rng)  # shape (Nt, 1)

model_weak.fit(U_noisy, t=t_eval)
model_weighted.fit(U_noisy, t=t_eval)
model_weighted2.fit(U_noisy, t=t_eval)

print("Unweighted weak SINDy model:")
model_weak.print()

print("\nWeighted weak SINDy (variance-based) model:")
model_weighted.print()

print("\nWeighted weak SINDy (constant weights) model:")
model_weighted2.print()
# Out:
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# Unweighted weak SINDy model:
# (x0)' = -0.476 x0
#
# Weighted weak SINDy (variance-based) model:
# (x0)' = -0.504 x0
#
# Weighted weak SINDy (constant weights) model:
# (x0)' = -0.516 x0
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(

# %% [markdown]
# The output should show three equations of the form
# $$
# u_t = \xi_1 u + \xi_2 u^2.
# $$
#
# The coefficient $\xi_1$ is expected to be close to $\lambda^\star = -0.5$, and ideally $\xi_2$ should be zero (no spurious nonlinearity).
#
# Next, perform a Monte Carlo experiment to quantify the benefit of weighting.

# %%
# %% 4.1 Extract coefficients for this realisation

def extract_coefficients(model, n_features=2):
    """
    Extract coefficients for a 1D model and pad to length n_features.
    Assumes features are ordered [u, u^2, ...] in the polynomial library.
    """
    Xi = model.coefficients()   # shape (n_active_features, 1)
    xi = np.zeros(n_features)
    m = min(n_features, Xi.shape[0])
    xi[:m] = Xi[:m, 0]
    return xi

xi_weak = extract_coefficients(model_weak)
xi_weighted = extract_coefficients(model_weighted)
xi_weighted2 = extract_coefficients(model_weighted2)

print("True coefficients:       [lam_true, 0] =", [lam_true, 0.0])
print("Unweighted coefficients:             ", xi_weak)
print("Weighted (variance) coeffs:         ", xi_weighted)
print("Weighted (const) coeffs:            ", xi_weighted2)
# Out:
# True coefficients:       [lam_true, 0] = [-0.5, 0.0]
# Unweighted coefficients:              [-0.4756022  0.       ]
# Weighted (variance) coeffs:          [-0.50351383  0.        ]
# Weighted (const) coeffs:             [-0.51597017  0.        ]

# %% [markdown]
# ## 5. Monte Carlo comparison
#
# Repeat the experiment over multiple noise realisations and record:
#
# - the error in the linear coefficient,
#   $\varepsilon^{(m)} = |\hat\lambda^{(m)} - \lambda^\star|$,
# - the spurious nonlinear coefficient magnitude
#   $\eta^{(m)} = |\hat\xi_2^{(m)}|$,
#
# for each method:
#
# - unweighted weak SINDy,
# - GLS with variance field,
# - GLS with constant weights.
#
# The expectation is that:
#
# - the variance-based GLS method reduces the error in $\hat\lambda$,
# - the variance-based GLS method reduces $|\hat\xi_2|$ (fewer spurious terms),
# - the constant-weight GLS behaves similarly to the unweighted case.

# %%
# %% 5. Monte Carlo study

n_trials = 500

err_lam_weak = []
err_lam_weighted = []
err_lam_weighted2 = []

spur_nonlin_weak = []
spur_nonlin_weighted = []
spur_nonlin_weighted2 = []

rng = np.random.default_rng(42)

for trial in tqdm(range(n_trials)):
    U_noisy = add_noise(u_clean, rng)

    # Use fresh optimizers for each trial to avoid reusing ensemble state
    opt1 = ps.EnsembleOptimizer(ps.STLSQ(threshold=0.1),
                                bagging=True, n_models=100)
    opt2 = ps.EnsembleOptimizer(ps.STLSQ(threshold=0.1),
                                bagging=True, n_models=100)
    opt3 = ps.EnsembleOptimizer(ps.STLSQ(threshold=0.1),
                                bagging=True, n_models=100)

    model_weak      = ps.SINDy(feature_library=weak_lib,
                               optimizer=opt1)
    model_weighted  = ps.SINDy(feature_library=weighted_weak_lib,
                               optimizer=opt2)
    model_weighted2 = ps.SINDy(feature_library=weighted_weak_lib2,
                               optimizer=opt3)

    model_weak.fit(U_noisy, t=t_eval)
    model_weighted.fit(U_noisy, t=t_eval)
    model_weighted2.fit(U_noisy, t=t_eval)

    xi_w = extract_coefficients(model_weak)
    xi_wgt = extract_coefficients(model_weighted)
    xi_wgt2 = extract_coefficients(model_weighted2)

    # errors in linear coefficient
    err_lam_weak.append(abs(xi_w[0] - lam_true))
    err_lam_weighted.append(abs(xi_wgt[0] - lam_true))
    err_lam_weighted2.append(abs(xi_wgt2[0] - lam_true))

    # magnitude of nonlinear coefficient (spurious term)
    spur_nonlin_weak.append(abs(xi_w[1]))
    spur_nonlin_weighted.append(abs(xi_wgt[1]))
    spur_nonlin_weighted2.append(abs(xi_wgt2[1]))

err_lam_weak = np.array(err_lam_weak)
err_lam_weighted = np.array(err_lam_weighted)
err_lam_weighted2 = np.array(err_lam_weighted2)

spur_nonlin_weak = np.array(spur_nonlin_weak)
spur_nonlin_weighted = np.array(spur_nonlin_weighted)
spur_nonlin_weighted2 = np.array(spur_nonlin_weighted2)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   0%|          | 1/500 [00:00<01:37,  5.11it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   0%|          | 2/500 [00:00<01:38,  5.05it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   1%|          | 3/500 [00:00<01:36,  5.13it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   1%|          | 4/500 [00:00<02:15,  3.67it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   1%|          | 5/500 [00:01<02:05,  3.95it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   1%|          | 6/500 [00:01<01:51,  4.42it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   1%|▏         | 7/500 [00:01<01:45,  4.66it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   2%|▏         | 8/500 [00:01<01:46,  4.63it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   2%|▏         | 9/500 [00:01<01:43,  4.75it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   2%|▏         | 10/500 [00:02<01:43,  4.73it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   2%|▏         | 11/500 [00:02<02:18,  3.53it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   2%|▏         | 12/500 [00:02<02:08,  3.80it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   3%|▎         | 13/500 [00:03<01:56,  4.17it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   3%|▎         | 14/500 [00:03<01:50,  4.39it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   3%|▎         | 15/500 [00:03<01:45,  4.61it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   3%|▎         | 16/500 [00:03<01:40,  4.82it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   3%|▎         | 17/500 [00:03<01:37,  4.96it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   4%|▎         | 18/500 [00:04<01:36,  4.99it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   4%|▍         | 19/500 [00:04<01:35,  5.03it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   4%|▍         | 20/500 [00:04<01:34,  5.10it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   4%|▍         | 21/500 [00:04<01:32,  5.20it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   4%|▍         | 22/500 [00:04<01:29,  5.34it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   5%|▍         | 23/500 [00:04<01:28,  5.42it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   5%|▍         | 24/500 [00:05<01:27,  5.44it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   5%|▌         | 25/500 [00:05<01:25,  5.53it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   5%|▌         | 26/500 [00:05<01:24,  5.61it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   5%|▌         | 27/500 [00:05<01:24,  5.63it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   6%|▌         | 28/500 [00:05<01:24,  5.61it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   6%|▌         | 29/500 [00:05<01:24,  5.59it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   6%|▌         | 30/500 [00:06<01:24,  5.54it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   6%|▌         | 31/500 [00:06<01:55,  4.08it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   6%|▋         | 32/500 [00:06<01:45,  4.42it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   7%|▋         | 33/500 [00:06<01:40,  4.64it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   7%|▋         | 34/500 [00:07<01:35,  4.88it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   7%|▋         | 35/500 [00:07<01:32,  5.03it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   7%|▋         | 36/500 [00:07<01:29,  5.19it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   7%|▋         | 37/500 [00:07<01:27,  5.28it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   8%|▊         | 38/500 [00:07<01:25,  5.39it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   8%|▊         | 39/500 [00:08<01:25,  5.42it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   8%|▊         | 40/500 [00:08<01:23,  5.48it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   8%|▊         | 41/500 [00:08<01:28,  5.17it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   8%|▊         | 42/500 [00:08<01:26,  5.27it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   9%|▊         | 43/500 [00:08<01:37,  4.67it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   9%|▉         | 44/500 [00:09<01:45,  4.32it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   9%|▉         | 45/500 [00:09<01:37,  4.66it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   9%|▉         | 46/500 [00:09<01:32,  4.93it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#   9%|▉         | 47/500 [00:09<01:31,  4.97it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  10%|▉         | 48/500 [00:09<01:28,  5.10it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  10%|▉         | 49/500 [00:10<01:56,  3.88it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  10%|█         | 50/500 [00:10<01:46,  4.21it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  10%|█         | 51/500 [00:10<01:41,  4.40it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  10%|█         | 52/500 [00:10<01:35,  4.67it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  11%|█         | 53/500 [00:11<01:32,  4.85it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  11%|█         | 54/500 [00:11<01:28,  5.02it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  11%|█         | 55/500 [00:11<01:26,  5.17it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  11%|█         | 56/500 [00:11<01:24,  5.28it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  11%|█▏        | 57/500 [00:11<01:22,  5.40it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  12%|█▏        | 58/500 [00:11<01:22,  5.38it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  12%|█▏        | 59/500 [00:12<01:21,  5.44it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  12%|█▏        | 60/500 [00:12<01:20,  5.47it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  12%|█▏        | 61/500 [00:12<01:22,  5.32it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  12%|█▏        | 62/500 [00:12<01:22,  5.30it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  13%|█▎        | 63/500 [00:12<01:24,  5.16it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  13%|█▎        | 64/500 [00:13<01:23,  5.24it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  13%|█▎        | 65/500 [00:13<01:28,  4.91it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  13%|█▎        | 66/500 [00:13<01:26,  5.03it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  13%|█▎        | 67/500 [00:13<01:25,  5.08it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  14%|█▎        | 68/500 [00:13<01:24,  5.13it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  14%|█▍        | 69/500 [00:14<02:07,  3.37it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  14%|█▍        | 70/500 [00:14<02:00,  3.58it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  14%|█▍        | 71/500 [00:14<01:55,  3.72it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  14%|█▍        | 72/500 [00:15<01:44,  4.09it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  15%|█▍        | 73/500 [00:15<01:36,  4.43it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  15%|█▍        | 74/500 [00:15<01:31,  4.64it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  15%|█▌        | 75/500 [00:15<01:29,  4.77it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  15%|█▌        | 76/500 [00:15<01:27,  4.86it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  15%|█▌        | 77/500 [00:16<01:24,  5.00it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  16%|█▌        | 78/500 [00:16<01:23,  5.05it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  16%|█▌        | 79/500 [00:16<01:22,  5.09it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  16%|█▌        | 80/500 [00:16<01:23,  5.04it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  16%|█▌        | 81/500 [00:16<01:21,  5.13it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  16%|█▋        | 82/500 [00:17<01:22,  5.09it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  17%|█▋        | 83/500 [00:17<01:21,  5.11it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  17%|█▋        | 84/500 [00:17<01:20,  5.16it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  17%|█▋        | 85/500 [00:17<01:36,  4.28it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  17%|█▋        | 86/500 [00:17<01:30,  4.55it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  94%|█████████▍| 472/500 [01:41<00:06,  4.64it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  95%|█████████▍| 473/500 [01:41<00:05,  4.66it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  95%|█████████▍| 474/500 [01:42<00:05,  4.74it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  95%|█████████▌| 475/500 [01:42<00:05,  4.80it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  95%|█████████▌| 476/500 [01:42<00:04,  4.83it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  95%|█████████▌| 477/500 [01:42<00:05,  3.97it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  96%|█████████▌| 478/500 [01:43<00:05,  4.01it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  96%|█████████▌| 479/500 [01:43<00:05,  4.06it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  96%|█████████▌| 480/500 [01:43<00:04,  4.04it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  96%|█████████▌| 481/500 [01:43<00:04,  4.07it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  96%|█████████▋| 482/500 [01:44<00:05,  3.54it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  97%|█████████▋| 483/500 [01:44<00:04,  3.66it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  97%|█████████▋| 484/500 [01:44<00:04,  3.54it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  97%|█████████▋| 485/500 [01:45<00:06,  2.48it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  97%|█████████▋| 486/500 [01:45<00:05,  2.47it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  97%|█████████▋| 487/500 [01:46<00:04,  2.75it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  98%|█████████▊| 488/500 [01:46<00:04,  2.89it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  98%|█████████▊| 489/500 [01:46<00:03,  3.16it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  98%|█████████▊| 490/500 [01:46<00:02,  3.38it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  98%|█████████▊| 491/500 [01:47<00:02,  3.32it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  98%|█████████▊| 492/500 [01:47<00:02,  3.68it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  99%|█████████▊| 493/500 [01:47<00:01,  4.04it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  99%|█████████▉| 494/500 [01:47<00:01,  4.26it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  99%|█████████▉| 495/500 [01:48<00:01,  4.43it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  99%|█████████▉| 496/500 [01:48<00:00,  4.49it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
#  99%|█████████▉| 497/500 [01:48<00:00,  4.63it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# 100%|█████████▉| 498/500 [01:48<00:00,  4.83it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# 100%|█████████▉| 499/500 [01:48<00:00,  4.20it/s]/Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Users/filippozacchei/anaconda3/envs/mfsindy/lib/python3.12/site-packages/pysindy/utils/_axes.py:125: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# 100%|██████████| 500/500 [01:49<00:00,  4.58it/s]

# %%
# %% 5.1 Summary statistics

def summary_stats(name, err, spur):
    print(f"{name}:")
    print(f"  |λ̂ - λ*| mean   = {err.mean():.3e}")
    print(f"  |λ̂ - λ*| median = {np.median(err):.3e}")
    print(f"  |ξ2| mean       = {spur.mean():.3e}")
    print(f"  |ξ2| median     = {np.median(spur):.3e}")
    print()

summary_stats("Unweighted weak", err_lam_weak, spur_nonlin_weak)
summary_stats("Weighted (variance)", err_lam_weighted, spur_nonlin_weighted)
summary_stats("Weighted (constant)", err_lam_weighted2, spur_nonlin_weighted2)
# Out:
# Unweighted weak:
#   |λ̂ - λ*| mean   = 2.024e-02
#   |λ̂ - λ*| median = 1.694e-02
#   |ξ2| mean       = 0.000e+00
#   |ξ2| median     = 0.000e+00
#
# Weighted (variance):
#   |λ̂ - λ*| mean   = 5.203e-03
#   |λ̂ - λ*| median = 4.499e-03
#   |ξ2| mean       = 0.000e+00
#   |ξ2| median     = 0.000e+00
#
# Weighted (constant):
#   |λ̂ - λ*| mean   = 8.626e-03
#   |λ̂ - λ*| median = 7.525e-03
#   |ξ2| mean       = 0.000e+00
#   |ξ2| median     = 0.000e+00

# %%
# %% 5.2 Visual comparison: boxplots of errors

plt.figure(figsize=(9, 4))

labels = ["Unweighted", "Weighted\n(var)", "Weighted\n(const)"]

plt.subplot(1, 2, 1)
plt.boxplot([err_lam_weak, err_lam_weighted, err_lam_weighted2],
            labels=labels, showfliers=False)
plt.ylabel(r"$|\hat{\lambda} - \lambda^\star|$")
plt.title("Linear coeff. error")

plt.subplot(1, 2, 2)
plt.boxplot([spur_nonlin_weak, spur_nonlin_weighted, spur_nonlin_weighted2],
            labels=labels, showfliers=False)
plt.ylabel(r"$|\hat{\xi}_2|$")
plt.title("Spurious nonlinear term")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/4s/l1d335rn5k19twqx3g8v_9140000gn/T/ipykernel_3313/1939612026.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([err_lam_weak, err_lam_weighted, err_lam_weighted2],
# /var/folders/4s/l1d335rn5k19twqx3g8v_9140000gn/T/ipykernel_3313/1939612026.py:14: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([spur_nonlin_weak, spur_nonlin_weighted, spur_nonlin_weighted2],

# %% [markdown]
# ## 6. Interpretation
#
# This experiment compares three feature libraries in otherwise identical SINDy
# setups:
#
# - unweighted weak-form SINDy (ordinary least squares in weak space),
# - weighted weak-form SINDy with GLS, using the true variance field
#   $\sigma^2(t)$,
# - weighted weak-form SINDy with constant weights (control).
#
# If the `WeightedWeakPDELibrary` is beneficial in the heteroskedastic setting,
# the results should show:
#
# - lower mean/median error $|\hat\lambda - \lambda^\star|$ for the variance-based
#   GLS method compared with the unweighted and constant-weight cases,
# - smaller magnitude of the spurious nonlinear coefficient $|\hat\xi_2|$.
#
# This provides an empirical validation that incorporating the variance field
# through GLS whitening in the weak space improves robustness of the identified
# model under heteroskedastic noise.
